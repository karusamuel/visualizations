# %% [markdown]
# # Introduction to Data Visualization
# ## Why Visualization Matters
#
# Data visualization transforms raw numbers into meaningful insights. While statistics such as mean and median are important, visuals allow us to detect patterns much faster than reading tables or spreadsheets.
#
# A well-designed chart can:
#
# - Reveal trends at a glance
# - Communicate insights clearly
# - Support better decision-making
#
# Humans process visual information far faster than text, making visualization a powerful analytical tool.
#
#
# ## The Power of Visualization
#
# Visualization is not just about presentation — it supports analysis itself.
#
# ### 1. Pattern Recognition
# Quickly identify trends, clusters, and anomalies.
#
# ### 2. Communication
# Explain findings clearly to non-technical audiences.
#
# ### 3. Exploration
# Discover hidden relationships within the data.
#
# ### 4. Validation
# Visually confirm statistical results and detect outliers or data quality issues.
#
# ## When Visualization Goes Wrong
#
# Poor visualizations can mislead rather than inform.
#
# Common mistakes include:
#
# - Truncated Y-axis — exaggerates small differences
# - Wrong chart type — e.g., too many slices in a pie chart
# - Misleading colors — inconsistent or emotionally confusing color use
# - Chart junk — unnecessary decorations that distract from the data
#
# **Golden Rule:** Every element in a visualization should serve the data. Clarity is more important than creativity.
#
# ## The Visualization Process
#
# Effective visualization follows a structured approach:
#
# 1. Define the question you want to answer
# 2. Understand your audience
# 3. Choose the appropriate chart type
# 4. Design for clarity (labels, scales, colors)
# 5. Test and refine

# %%
# imports 
import pandas as pd
import numpy as np

# %%
# data loading

df_sales = pd.read_csv("./sales_data.csv")
df_sales.head()
# Out:
#    Transaction_ID Region Department Quarter  Units_Sold  Unit_Price  Revenue  \
# 0               1   East       Home      Q2          33       40.23  1327.59
# 1               2   West       Home      Q4          14       51.89   726.46
# 2               3  North     Sports      Q3          20       40.34   806.80
# 3               4   East       Home      Q3          20       48.98   979.60
# 4               5   East      Books      Q1          17       57.16   971.72
#
#           Cost      Profit  Profit_Margin  Year
# 0  1106.103311  221.486689         0.1668  2024
# 1   391.302584  335.157416         0.4614  2024
# 2   544.467644  262.332356         0.3252  2024
# 3   723.364220  256.235780         0.2616  2024
# 4   817.217207  154.502793         0.1590  2024

# %%
df_sales["Year"] = df_sales["Year"].apply(lambda x: np.random.choice([2023,2024,2025,2026]))

# %%
df_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction_ID  10000 non-null  int64
#  1   Region          10000 non-null  str
#  2   Department      10000 non-null  str
#  3   Quarter         10000 non-null  str
#  4   Units_Sold      10000 non-null  int64
#  5   Unit_Price      10000 non-null  float64
#  6   Revenue         10000 non-null  float64
#  7   Cost            10000 non-null  float64
#  8   Profit          10000 non-null  float64
#  9   Profit_Margin   10000 non-null  float64
#  10  Year            10000 non-null  int64
# dtypes: float64(5), int64(3), str(3)
# memory usage: 859.5 KB

# %%
df_sales.describe()
# Out:
#        Transaction_ID    Units_Sold    Unit_Price       Revenue          Cost  \
# count     10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5000.50000     20.042200     50.149715   1005.311293    706.417612
# std        2886.89568      4.525204     15.102271    385.308281    298.593462
# min           1.00000      6.000000      0.020000      0.400000      0.276144
# 25%        2500.75000     17.000000     40.070000    734.595000    494.855325
# 50%        5000.50000     20.000000     50.160000    972.215000    666.083554
# 75%        7500.25000     23.000000     60.272500   1233.577500    879.153998
# max       10000.00000     39.000000    103.610000   2913.750000   2426.759576
#
#              Profit  Profit_Margin          Year
# count  10000.000000   10000.000000  10000.000000
# mean     298.893681       0.297735   2024.520800
# std      169.376367       0.116256      1.115658
# min        0.123856       0.100000   2023.000000
# ...

# %%
df_sales = df_sales.iloc[:1000]
df_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction_ID  1000 non-null   int64
#  1   Region          1000 non-null   str
#  2   Department      1000 non-null   str
#  3   Quarter         1000 non-null   str
#  4   Units_Sold      1000 non-null   int64
#  5   Unit_Price      1000 non-null   float64
#  6   Revenue         1000 non-null   float64
#  7   Cost            1000 non-null   float64
#  8   Profit          1000 non-null   float64
#  9   Profit_Margin   1000 non-null   float64
#  10  Year            1000 non-null   int64
# dtypes: float64(5), int64(3), str(3)
# memory usage: 86.1 KB

# %% [markdown]
# # Introduction to Matplotlib
#
# ## What Is Matplotlib?
#
# Matplotlib is the foundation of Python visualization.
# It offers complete control over every element of a plot. While it requires more effort than higher-level libraries, it provides maximum flexibility and customization.

# %%
# import 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Matplotlib Architecture
#
# Understanding the hierarchy is essential.
#
# ### 1. Figure
# The overall canvas or window that holds everything.
#
# Think: The entire page.
#
# ### 2. Axes
# The actual plotting area where data is drawn.
# A Figure can contain multiple Axes (subplots).
#
# Think: The individual charts on the page.
#
# ### 3. Axis
# The number lines (x-axis and y-axis) with ticks and labels.
#
# Think: The rulers with numbers.
#
# Important distinction:
# - **Axes** = the full plot area
# - **Axis** = the scale (x or y)
#
# ## Two Ways to Use Matplotlib
#
# ### 1. Pyplot Interface (MATLAB-style)
#
# - Simpler and quicker
# - Less control
# - Not ideal for complex or professional projects
#
# Example pattern:
# ```python
# import matplotlib.pyplot as plt
# plt.plot(x, y)
# plt.xlabel("X")
# plt.ylabel("Y")
# plt.title("Title")
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt
plt.boxplot(x=df_sales["Profit"])
plt.show()

# %%
# example
plt.bar(df_sales["Department"],df_sales["Profit"])
plt.show()

# %%
# example 2
plt.bar(df_sales["Department"],df_sales["Profit"])
plt.xlabel("Department")
plt.ylabel("Profit (Ksh)")
plt.title("Profit Per Deparment in (Ksh)")
plt.show()

# %%
# example 2
plt.bar(df_sales["Quarter"],df_sales["Profit"])
plt.xlabel("Quarter")
plt.ylabel("Profit (Ksh)")
plt.title("Profit Per Quarter in (Ksh)")
plt.show()

# %% [markdown]
# ### 2. Object-Oriented (OO) Interface — Recommended
#
# - Explicit and scalable
# - More control
# - Best practice for professional work
#
# Example pattern:
# ```python
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots()
# ax.plot(x, y)
# ax.set_xlabel("X")
# ax.set_ylabel("Y")
# ax.set_title("Title")
# plt.show()
# ```
#
# Best practice:
# Always prefer `fig, ax = plt.subplots()`.

# %%
import matplotlib.pyplot as plt 

fig,ax = plt.subplots()
ax.bar(df_sales["Region"],df_sales["Profit"])
plt.show()

# %%
# example
fig,ax = plt.subplots()
ax.bar(df_sales["Department"],df_sales["Profit"])
ax.set_xlabel("Depertment")
ax.set_ylabel("Profit (Ksh)")
ax.set_title("Profit Per Deperment in (Ksh)")
plt.show()

# %% [markdown]
# ## Common Plot Types
#
# ### 1. Line Plot
# Use for trends over time.

# %%
yearly_profit = df_sales.groupby("Year")["Profit"].mean().reset_index()

fig, ax = plt.subplots()
ax.plot(yearly_profit["Year"], yearly_profit["Profit"])
ax.set_title("Profit Over Years")
ax.set_xlabel("Years")
ax.set_ylabel("Profit")
plt.show()

# %% [markdown]
# ### 2. Scatter Plot
# Use for relationships between two continuous variables.

# %%
# example
fig,ax = plt.subplots()
ax.scatter(df_sales["Cost"],df_sales["Profit"])
ax.set_xlabel("Cost (ksh)")
ax.set_ylabel("Profit (Ksh)")
ax.set_title("Profit vs Cost)")
plt.show()

# %% [markdown]
# ### 3. Bar Chart
# Use for comparing categories.

# %%
fig,ax = plt.subplots()
ax.bar(df_sales["Region"],df_sales["Cost"])
ax.set_xlabel("Department")
ax.set_ylabel("Cost (Ksh)")
ax.set_title("Cost Per Deperment)")
plt.show()

# %% [markdown]
# ### 4. Histogram
# Use for visualizing distributions of continuous data.
#
# These four cover most common analytical needs.

# %%
# example

fig,ax = plt.subplots()
ax.hist(df_sales["Cost"])
ax.set_xlabel("Density")
ax.set_ylabel("Cost (Ksh)")
ax.set_title("Cost Distribution)")
plt.show()

# %% [markdown]
# ## Customization Essentials
#
# Professional plots require refinement beyond defaults.
#
# ### Colors
# - Named colors (`"blue"`)
# - Hex codes (`"#FF5733"`)
# - RGB tuples

# %%
# example 1
fig,ax = plt.subplots()
ax.hist(df_sales["Cost"],color="#51b34a")
ax.set_xlabel("Density")
ax.set_ylabel("Cost (Ksh)")
ax.set_title("Cost Distribution)")
plt.show()

# %%
# example 2
fig,ax = plt.subplots()
ax.hist(df_sales["Cost"],color="#31D4B3")
ax.set_xlabel("Density")
ax.set_ylabel("Cost (Ksh)")
ax.set_title("Cost Distribution)")
plt.show()

# %% [markdown]
# ### Figure Size
# ```python
# fig, ax = plt.subplots(figsize=(12, 8))
# ```

# %%
# example 2
fig,ax = plt.subplots(figsize=(12, 6))
ax.hist(df_sales["Cost"],color="#FF5733")
ax.set_xlabel("Density")
ax.set_ylabel("Cost (Ksh)")
ax.set_title("Cost Distribution)")
plt.show()

# %% [markdown]
# ### Grid
# ```python
# ax.grid(True)
# ``

# %%
# example
fig,ax = plt.subplots()
ax.hist(df_sales["Cost"],color="aqua")
ax.grid(True)
ax.set_xlabel("Density")
ax.set_ylabel("Cost (Ksh)")
ax.set_title("Cost Distribution)")
plt.show()

# %% [markdown]
# ## Multiple Subplots
#
# To compare related visuals, create multiple Axes within one Figure.
#
# Example structure:
# ```python
# fig, axes = plt.subplots(2, 2)
# axes[0, 0].plot(...)
# axes[0, 1].scatter(...)
# axes[1, 0].bar(...)
# axes[1, 1].hist(...)
# plt.tight_layout()
# plt.show()
# ```
#
# Important:
# - Use `plt.tight_layout()` to prevent overlapping labels.
# - Use `axes[row, column]` for 2D grids.

# %%
# example

fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Top-left: Line plot (example)
axes[0, 0].plot(df_sales["Cost"])
axes[0, 0].set_title("Cost Trend")

# Top-right: Scatter plot
axes[0, 1].scatter(df_sales["Cost"], df_sales["Profit"])
axes[0, 1].set_title("Cost vs Profit")
axes[0, 1].grid(True, alpha=0.3)

# Bottom-left: Bar chart
axes[1, 0].bar(df_sales["Department"], df_sales["Cost"])
axes[1, 0].set_title("Cost by Department")
axes[1, 0].tick_params(axis='x', rotation=45)
axes[1, 0].grid(True, axis='y', alpha=0.3)

# Bottom-right: Histogram
axes[1, 1].hist(df_sales["Cost"], color="aqua", edgecolor="black")
axes[1, 1].set_title("Distribution of Cost")
axes[1, 1].grid(True, axis='y', alpha=0.3)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Saving Plots
#
# Export plots for reports or publications:
#
# ```python
# plt.savefig("chart.png", dpi=300, bbox_inches="tight")
# ```
#
# Key parameters:
# - `dpi=300` → high resolution
# - `bbox_inches="tight"` → removes extra whitespace
# - `transparent=True` → transparent background
# - Can save as PNG, PDF, or SVG

# %%
# example 
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Top-left: Line plot (example)
axes[0, 0].plot(df_sales["Cost"])
axes[0, 0].set_title("Cost Trend")

# Top-right: Scatter plot
axes[0, 1].scatter(df_sales["Cost"], df_sales["Profit"])
axes[0, 1].set_title("Cost vs Profit")
axes[0, 1].grid(True, alpha=0.3)

# Bottom-left: Bar chart
axes[1, 0].bar(df_sales["Department"], df_sales["Cost"])
axes[1, 0].set_title("Cost by Department")
axes[1, 0].tick_params(axis='x', rotation=45)
axes[1, 0].grid(True, axis='y', alpha=0.3)

# Bottom-right: Histogram
axes[1, 1].hist(df_sales["Cost"], color="aqua", edgecolor="black")
axes[1, 1].set_title("Distribution of Cost")
axes[1, 1].grid(True, axis='y', alpha=0.3)

# Adjust layout
plt.tight_layout()
plt.savefig("multichart.png",dpi=300,bbox_inches="tight")

# %%
import matplotlib.pyplot as plt

# %%
# matlab

plt.hist(df_sales["Cost"])
plt.title("Cost Distribution")
plt.xlabel("Cost")
plt.ylabel("Count")

plt.show()

# %%
fig,ax = plt.subplots()
ax.hist(df_sales["Cost"])
ax.set_title("Cost Distribution")
plt.show()

# %%
fig,ax = plt.subplots()
ax.hist(df_sales["Cost"])
ax.hist(df_sales["Profit"],color="green",alpha=0.5)
ax.set_title("Cost Distribution")
ax.axhline(150,color="red")
ax.text(1500,160,"Target")
plt.show()

# %%
fig,axes = plt.subplots(1,2)
axes[0].hist(df_sales["Cost"])
axes[0].set_title("Cost Distribution")

axes[1].hist(df_sales["Profit"])
axes[1].set_title("Profit Distribution")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Introduction to Seaborn
# ## What Is Seaborn?
#
# Seaborn is a statistical visualization library built on top of matplotlib.  it is designed to produce attractive and informative statistical graphics with minimal code.
#
# Seaborn does not replace matplotlib — it enhances it. Under the hood, seaborn generates matplotlib figures, which means you can still customize them using matplotlib tools.
#
#
#
# ## Why Use Seaborn?
#
# ### 1. Beautiful by Default
# Produces professional-looking plots without manual styling.
#
# ### 2. Native Pandas Integration
# Works directly with DataFrames. You pass `data=df` and reference columns by name.
#
# ### 3. Statistical Focus
# Built-in support for:
# - Confidence intervals
# - Regression lines
# - Distributions
# - Aggregations
#
# ### 4. Less Code
# Complex visualizations often require only one or two lines.

# %% [markdown]
# ## Getting Started
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
#
# sns.set_style("whitegrid")
# sns.set_palette("deep")
# ```
#
# Seaborn also includes built-in datasets for practice:
#
# ```python
# sns.load_dataset("tips")
# sns.load_dataset("iris")
# sns.load_dataset("titanic")
# ```

# %%
df_sales.head()
# Out:
#    Transaction_ID Region Department Quarter  Units_Sold  Unit_Price  Revenue  \
# 0               1   East       Home      Q2          33       40.23  1327.59
# 1               2   West       Home      Q4          14       51.89   726.46
# 2               3  North     Sports      Q3          20       40.34   806.80
# 3               4   East       Home      Q3          20       48.98   979.60
# 4               5   East      Books      Q1          17       57.16   971.72
#
#           Cost      Profit  Profit_Margin  Year
# 0  1106.103311  221.486689         0.1668  2025
# 1   391.302584  335.157416         0.4614  2025
# 2   544.467644  262.332356         0.3252  2026
# 3   723.364220  256.235780         0.2616  2023
# 4   817.217207  154.502793         0.1590  2023

# %% [markdown]
# ## Styling and Themes
#
# Seaborn provides global styling controls.
#
# ### Styles
# ```python
# sns.set_style("darkgrid")
# sns.set_style("whitegrid")
# sns.set_style("white")
# sns.set_style("ticks")
# ```

# %%
import seaborn as sns

# %%
# example
import seaborn as sns
sns.set_style("whitegrid")
sns.set_palette("husl")
sns.set_context("paper")
sns.histplot(data=df_sales,x="Cost",hue="Department")
plt.show()

# %%
sns.barplot(data=df_sales,x="Department",y="Profit",hue="Department")
# Out:
# <Axes: xlabel='Department', ylabel='Profit'>

# %% [markdown]
# ### Color Palettes
# ```python
# sns.set_palette("deep")
# sns.set_palette("husl")
# sns.set_palette("Set2")
# sns.set_palette("viridis")
# ```

# %%
# example
sns.set_palette("deep")

# %% [markdown]
# ### Context (Scaling)
# ```python
# sns.set_context("paper")
# sns.set_context("notebook")
# sns.set_context("talk")
# sns.set_context("poster")
# ```
#
# Set style, palette, and context at the start of your notebook so all plots inherit the settings.

# %%
# example

sns.set_context("paper")

# %% [markdown]
# ## Core Seaborn Plot Types
#
# ### Distribution Plots
# - `histplot()`
# - `kdeplot()`
# - `violinplot()`
#
# Used to understand how data is distributed.

# %%
# example
sns.histplot(data=df_sales,x="Cost",kde=True)
plt.show()

# %%
# example
sns.kdeplot(data=df_sales,x="Profit")
# Out:
# <Axes: xlabel='Profit', ylabel='Density'>

# %%
sns.violinplot(data=df_sales,x="Profit")
# Out:
# <Axes: xlabel='Profit'>

# %% [markdown]
# ### Categorical Plots
# - `barplot()`
# - `countplot()`
#
# Used to compare values across categories.

# %%
# example
sns.barplot(data=df_sales,x="Region",y="Profit")
# Out:
# <Axes: xlabel='Region', ylabel='Profit'>

# %%
# example 
sns.countplot(data=df_sales,x="Department",hue="Region")
plt.show()

# %% [markdown]
# ### Relationship Plots
# - `scatterplot()`
# - `regplot()`
# - `heatmap()`
#
# Used to analyze relationships between variables.

# %%
# example
sns.scatterplot(df_sales,x="Cost",y="Profit")

# %%
fig,ax = plt.subplots()
# example
sns.scatterplot(df_sales,x="Cost",y="Profit",ax=ax)
ax.axvline(1500)
ax.annotate("point of diminishing cost",xytext=(2000,400),
            xy=(1500,600),
            arrowprops=dict(color="red",width=1))
# Out:
# Text(2000, 400, 'point of diminishing cost')

# %%
#example
sns.regplot(df_sales,x="Profit",y="Cost")
# Out:
# <Axes: xlabel='Profit', ylabel='Cost'>

# %% [markdown]
# ## Advanced Features
#
# ### Pair Plot
#
# Displays all pairwise relationships in a dataset.
#
# ```python
# sns.pairplot(df, hue="category")
# plt.show()
# ```
#
# Useful for exploratory data analysis and detecting hidden correlations.

# %%
# example 
sns.pairplot(data=df_sales,hue="Region")
plt.show()

# %% [markdown]
# ### FacetGrid
#
# Creates multiple plots split by category.
#
# ```python
# g = sns.FacetGrid(df, col="department")
# g.map(sns.histplot, "salary")
# plt.show()
# ```
#
# Ideal for comparing patterns across subgroups.

# %%
# example

g = sns.FacetGrid(df_sales, col="Department")
g.map(sns.histplot, "Profit")
plt.show()

# %%
g = sns.FacetGrid(df_sales,col="Region")
g.map(sns.kdeplot,"Profit")

# %% [markdown]
# ## Seaborn vs Matplotlib
#
# ### Use Seaborn When:
# - Working with DataFrames
# - Performing statistical visualization
# - Exploring data quickly
# - Comparing across categories
# - Wanting clean visuals with minimal setup
#
# ### Use Matplotlib When:
# - You need precise customization
# - Creating highly specialized plots
# - Adding complex annotations
# - Formatting for publication requirements
#
# Best practice: Start with seaborn. If you need deeper customization, modify the resulting matplotlib objects.
#
#
#
# ## Combining Seaborn and Matplotlib
#
# Since seaborn plots are matplotlib figures, you can combine them:
#
# ```python
# fig, ax = plt.subplots(figsize=(10, 6))
#
# sns.boxplot(data=df, x="department", y="salary", ax=ax)
#
# ax.set_title("Salary by Department")
# ax.axhline(y=75000, linestyle="--")
# plt.tight_layout()
# plt.show()
# ```
#
# Use seaborn for plotting and matplotlib for finishing touches.

# %%
# example

fig, ax = plt.subplots(figsize=(10, 6))

sns.countplot(data=df_sales,x="Department",ax=ax)

ax.set_title("Salary by Department")
ax.axhline(y=len(df_sales)/6, linestyle="--",color="red")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Chart Selection Cheat Sheet
#
# | Goal | Best Chart | Function |
# |------|------------|----------|
# | Compare categories | Bar chart | sns.barplot() |
# | Show distribution | Histogram | sns.histplot() |
# | Find outliers | Box plot | sns.boxplot() |
# | Show correlation | Scatter plot | sns.scatterplot() |
# | Track over time | Line chart | ax.plot() |
# | Compare many variables | Heatmap | sns.heatmap() |
# | Count occurrences | Count plot | sns.countplot() |
# | See all relationships | Pair plot | sns.pairplot() |

# %% [markdown]
# # Customization & Best Practices
#
# # The CLARITY Principle
#
# Use this acronym for professional visualizations:
#
# ### C — Clear Labels
# Every axis, legend, and title must be self-explanatory.
# No abbreviations without context.
#
# ### L — Legible Text
# Font size matters.
# - Minimum 10pt for body text
# - 12–14pt for titles
# Avoid tiny unreadable labels.
#
# ### A — Appropriate Colors
# Use color purposefully.
# Consider colorblind viewers. Red and green together is problematic for about 8% of men.
#
# ### R — Relevant Data Only
# Remove chart junk, unnecessary gridlines, and 3D effects.
# If it does not improve understanding, delete it.
#
# ### I — Intuitive Design
# Follow conventions:
# - Time flows left to right
# - Larger values appear higher
# - Positive values go up or right
#
# ### T — Truthful Representation
# Start axes at zero for bar charts.
# Do not manipulate scales to exaggerate results.
# Be honest with data.
#
# ### Y — Your Audience First
# Design for viewers, not yourself.
# - Executives need summaries
# - Analysts need detail
#
# Know your audience.
#
#
# # Essential Customizations
#
# | Area | Key Principle | When to Use | Best Practices | Example Elements |
# |------|--------------|------------|---------------|-----------------|
# | Titles & Labels | Provide clear context | All visualizations | Title answers “What am I looking at?”; include units; add year/date | Descriptive title, labeled axes, units in parentheses |
# | Sequential Colors | Show ordered progression | Low → high data (temperature, revenue, population) | Use gradual light-to-dark palettes | `Blues`, `YlOrRd`, `viridis` |
# | Diverging Colors | Show deviation from midpoint | Correlation, profit vs loss, above/below average | Use contrasting colors around neutral center | `RdBu`, `coolwarm`, `PiYG` |
# | Categorical Colors | Distinguish separate groups | Unordered categories | Use clearly distinct hues; ensure colorblind safety | `Set2`, `husl`, `tab10` |
# | Accessibility | Ensure inclusivity | All charts | Avoid red–green combos; use colorblind-safe palettes; add patterns/shapes if needed | `Set2` palette |
# | Annotations | Highlight insights | When key findings need emphasis | Add reference lines, arrows, labels, shaded regions | `ax.axhline()`, `ax.text()`, `ax.annotate()`, `ax.axvspan()` |
# | Gridlines | Improve readability | Most charts | Keep subtle; reduce clutter; adjust transparency | Light dashed horizontal lines |
# | Whitespace & Cleanup | Improve clarity | All visualizations | Remove top/right spines; apply `tight_layout()` | `ax.spines[...]`, `plt.tight_layout()` |
# | Chart-Specific Grid Rule | Match grid to chart type | Bar vs Scatter | Bar: horizontal only; Scatter: subtle both axes; avoid bold grids | `ax.grid(axis='y', alpha=0.3)` |
#
#
# # Storytelling with Data
#
# Great visualizations tell stories.
#
# ### 1. Start With Context
# Explain why it matters before showing the chart.
#
# ### 2. Highlight the Insight
# Use annotations and color to show the key takeaway.
#
# ### 3. Guide the Eye
# Visual hierarchy matters:
# - Larger text = more important
# - Brighter color = focus
# - Reference lines = context
#
# ### 4. End With Action
# Translate insight into decision.
# What should viewers do next?

# %%
# gap

# %% [markdown]
# # Design Principles for Effective Charts
# | Section | Core Idea | Key Concepts | Practical Application |
# |----------|------------|--------------|------------------------|
# | Why Design Matters | Design makes data clear, honest, impactful | Clarity > decoration; communication > aesthetics | Remove clutter, focus on message |
# | Visualization Purpose | Different goals require different design | Exploration, Explanation, Presentation, Monitoring | Exploration = fast & messy; Presentation = polished & persuasive |
# | Data-Ink Ratio | Maximize data, minimize non-data elements | Remove chart junk; every element must serve purpose | Remove 3D, heavy grids, decorative icons, unnecessary borders |
# | Chart Junk | Distracting elements that add no value | Gradients, shadows, rainbow colors, redundant labels | Simplify to flat design, limited color palette |
# | Data-Ink | Essential visual elements | Data marks, labels, titles, legends (if needed) | Keep thin axis lines, subtle grids, clear titles |
# | Visual Hierarchy | Guide viewer attention intentionally | Size, color, contrast, weight, position | Largest text = most important; highlight key data |
# | Reading Order | Natural eye movement pattern | Title → Data → Axes → Legend | Place title top-left/top-center |
# | Size Principle | Bigger = more important | Title 1.5–2× axis label size | Clear size distinction across elements |
# | Color & Contrast | Draw focus with emphasis | Bright for key data; muted for support | One highlight color; gray background elements |
# | Weight (Typography) | Bold = emphasis | Reserve bold for titles & key insight | Avoid bolding everything |
# | Position | Placement affects attention | Top-left read first; bottom-right read last | Put notes in bottom-right |
# | Gestalt: Proximity | Close elements feel related | Group related charts & labels | Use whitespace to separate sections |
# | Gestalt: Similarity | Similar visuals are grouped | Same color = same category | Keep category colors consistent |
# | Gestalt: Enclosure | Borders create groups | Subtle background grouping | Avoid excessive boxing |
# | Gestalt: Continuity | Eyes follow smooth paths | Use line charts for trends | Align elements cleanly |
# | Gestalt: Closure | Brain completes shapes | Minimal borders needed | Partial gridlines sufficient |
# | Gestalt: Figure-Ground | Separate foreground from background | Data = foreground; grid = background | High contrast data, muted support |
# | Simplicity | Less is more | Reduce cognitive load | Limit colors (3–5 max), split crowded charts |
# | Consistency | Predictability builds trust | Same colors, fonts, layout across charts | Create and follow a style guide |
# | Style Guide | Standardized visual rules | Defined colors, fonts, layout | Apply across all charts consistently |
# .

# %%
# gap

# %% [markdown]
# # Titles, Labels, and Legends
#
# | Section | Core Idea | Key Concepts | Practical Application |
# |----------|------------|--------------|------------------------|
# | Why Labels Matter | Charts must be self-explanatory | Context, clarity, guidance | Chart should pass 5-second understanding test |
# | Chart Titles | Title = headline of your story | Descriptive vs Insight titles | Use insight titles for presentations |
# | Descriptive Titles | State what the chart shows | Neutral, factual | “Revenue by Region (2024)” |
# | Insight Titles | State key takeaway | Action-oriented, specific | “Revenue Increased 23% YoY” |
# | Title Best Practices | Clear hierarchy & readability | 18–24px, bold, top placement | Make title 1.5–2× larger than axis labels |
# | Subtitles | Add context without clutter | Timeframe, units, source | Place below title in smaller font |
# | Axis Labels | Explain what is measured | Include units and context | “Revenue ($ Millions)” |
# | X-Axis Labels | Categories or time | Specific, not vague | “Month (2024)” |
# | Y-Axis Labels | Quantities or metrics | Always include units | “Market Share (%)” |
# | Axis Formatting | Clean numeric presentation | 0–2 decimals, readable dates | 1.2M instead of 1,200,000 |
# | Legend Decision | Use only when necessary | Avoid extra cognitive load | Prefer direct labeling when possible |
# | When to Use Legends | Multiple overlapping series | 5+ categories, limited space | Keep minimal, no heavy border |
# | Direct Labeling | Faster comprehension | Label data near marks | Use text above bars or end of lines |
# | Legend Design | Keep subtle and organized | Top-right, small font, no box | Match order with data |
# | Annotations | Highlight key insights | Brief, strategic, specific | Mark anomalies, milestones, targets |
# | Good Annotation | Adds insight, not clutter | Short sentence + visual cue | Arrow to spike with % increase |
# | Gridlines | Support reading values | Light, thin, horizontal only | Alpha ~0.3, behind data |
# | When to Remove Gridlines | Trend > precision | Small dashboards, labeled bars | Cleaner, minimalist design |
# | Self-Explanatory Test | Chart stands alone | No verbal explanation needed | Viewer understands in ≤5 seconds |

# %%
# gap

# %% [markdown]
# # Color Theory and Accessibility
#
# | Section | Core Idea | Key Concepts | Practical Application |
# |----------|------------|--------------|------------------------|
# | Why Color Matters | Color guides interpretation & emotion | 8% of men have color blindness | Design so everyone can interpret data |
# | Color Psychology | Colors carry meaning | Red=danger, Green=growth, Blue=trust | Match color meaning to data meaning |
# | Cultural Awareness | Color meanings vary globally | Red=lucky (China), danger (West) | Know your audience context |
# | Sequential Palette | Ordered data (low → high) | Light → Dark intensity | Use single-hue gradients (e.g., Blues) |
# | Diverging Palette | Data with meaningful midpoint | Two colors around neutral center | Use for profit/loss, above/below avg |
# | Categorical Palette | Distinct unordered groups | Visually distinct colors | Limit to 3–7 categories |
# | Rainbow Warning | Avoid rainbow gradients | Poor perceptual order | Use perceptually uniform palettes instead |
# | Red-Green Blindness | Most common type (~7% men) | Red & green indistinguishable | Never rely solely on red vs green |
# | Safe Combinations | Accessible color pairs | Blue+Orange, Blue+Magenta | Use high hue & brightness contrast |
# | Avoided Combinations | Hard to distinguish | Red+Green, Orange+Red | Avoid for critical comparisons |
# | Accessibility Enhancements | Don’t rely only on color | Patterns, shapes, labels | Add hatching, markers, direct labels |
# | Contrast Principle | Ensure readability | 4.5:1 ratio for normal text | Dark text on light background |
# | Background Choice | Neutral improves clarity | White or light gray best | Avoid colored backgrounds |
# | Squint Test | Quick readability check | Data should stand out | Increase contrast if data fades |
# | Professional Palette | Consistent color system | Brand colors + safe defaults | Define & reuse a standard palette |
# | Recommended Palettes | Tested for accessibility | ColorBrewer, Viridis, Tab10 | Use seaborn "colorblind" palette |
